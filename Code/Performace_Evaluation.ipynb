# %% [markdown]
# # Performance Evaluation
#
# This notebook is used to show the performance of ORTEGA-PySpark under different configuration setting and data sampling rate, which is not part of interaction analysis.

# %% [markdown]
# # Concurrent Interaction Performance
# ## Earl Subset
# ### Sampling Rates

# %%
# %%time
"""
sampling rate: 10h
--conf spark.driver.memory=6g ^
--conf spark.executor.memory=10g
"""
run_spatiotemporal_join(one_bird_pairs, id_field, join_id_field, sampling_rate_threshold, df, data_dir, broadcast_bounds, broadcast_spatial_bounds, attribute_list, select_columns, f"test_Earl_6_10_{sampling_rate}h")
# Out:
# Writing status every 1000 pairs
# Processing time for pair David-Earl: 4.53 seconds
# Processing time for pair Earl-Leo: 6.08 seconds
# Processing time for pair Earl-Julie: 3.72 seconds
# Processing time for pair Earl-MooMoo: 2.31 seconds
# Processing time for pair Earl-Irma: 3.72 seconds
# Processing time for pair Earl-Gifford: 16.41 seconds
# Processing time for pair Earl-Hugh: 8.09 seconds
# Processing time for pair Earl-Ethan: 11.08 seconds
# CPU times: total: 312 ms
# Wall time: 57.1 s

# %%
# %%time
"""
sampling rate: 9h
--conf spark.driver.memory=6g ^
--conf spark.executor.memory=10g
"""
run_spatiotemporal_join(one_bird_pairs, id_field, join_id_field, sampling_rate_threshold, df, data_dir, broadcast_bounds, broadcast_spatial_bounds, attribute_list, select_columns, f"test_Earl_6_10_{sampling_rate}h")
# Out:
# Writing status every 1000 pairs
# Processing time for pair David-Earl: 5.58 seconds
# Processing time for pair Earl-Julie: 5.40 seconds
# Processing time for pair Earl-MooMoo: 2.72 seconds
# Processing time for pair Earl-Leo: 6.33 seconds
# Processing time for pair Earl-Irma: 3.02 seconds
# Processing time for pair Earl-Gifford: 14.38 seconds
# Processing time for pair Earl-Hugh: 7.06 seconds
# Processing time for pair Earl-Ethan: 7.74 seconds
# CPU times: total: 328 ms
# Wall time: 53.8 s

# %%
# %%time
"""
sampling rate: 8h
--conf spark.driver.memory=6g ^
--conf spark.executor.memory=10g
"""
run_spatiotemporal_join(one_bird_pairs, id_field, join_id_field, sampling_rate_threshold, df, data_dir, broadcast_bounds, broadcast_spatial_bounds, attribute_list, select_columns, f"test_Earl_6_10_{sampling_rate}h")
# Out:
# Writing status every 1000 pairs
# Processing time for pair Earl-Hugh: 11.51 seconds
# Processing time for pair Earl-MooMoo: 6.41 seconds
# Processing time for pair Earl-Ethan: 13.82 seconds
# Processing time for pair Earl-Irma: 7.92 seconds
# Processing time for pair Earl-Leo: 9.20 seconds
# Processing time for pair Earl-Julie: 6.91 seconds
# Processing time for pair Earl-Gifford: 16.61 seconds
# Processing time for pair David-Earl: 8.44 seconds
# CPU times: total: 438 ms
# Wall time: 1min 22s

# %%
# %%time
"""
sampling rate: 7h
--conf spark.driver.memory=6g ^
--conf spark.executor.memory=10g
"""
run_spatiotemporal_join(one_bird_pairs, id_field, join_id_field, sampling_rate_threshold, df, data_dir, broadcast_bounds, broadcast_spatial_bounds, attribute_list, select_columns, f"test_Earl_6_10_{sampling_rate}h")
# Out:
# Writing status every 1000 pairs
# Processing time for pair Earl-Hugh: 14.12 seconds
# Processing time for pair Earl-MooMoo: 5.44 seconds
# Processing time for pair Earl-Ethan: 13.53 seconds
# Processing time for pair Earl-Irma: 7.28 seconds
# Processing time for pair Earl-Leo: 9.95 seconds
# Processing time for pair Earl-Julie: 8.22 seconds
# Processing time for pair Earl-Gifford: 21.05 seconds
# Processing time for pair David-Earl: 9.06 seconds
# CPU times: total: 422 ms
# Wall time: 1min 31s

# %%
# %%time
"""
sampling rate: 6h
--conf spark.driver.memory=6g ^
--conf spark.executor.memory=10g
"""
run_spatiotemporal_join(one_bird_pairs, id_field, join_id_field, sampling_rate_threshold, df, data_dir, broadcast_bounds, broadcast_spatial_bounds, attribute_list, select_columns, f"test_Earl_6_10_{sampling_rate}h")
# Out:
# Writing status every 1000 pairs
# Processing time for pair Earl-Hugh: 12.20 seconds
# Processing time for pair Earl-MooMoo: 6.64 seconds
# Processing time for pair Earl-Ethan: 14.87 seconds
# Processing time for pair Earl-Irma: 10.14 seconds
# Processing time for pair Earl-Leo: 11.61 seconds
# Processing time for pair Earl-Julie: 8.97 seconds
# Processing time for pair Earl-Gifford: 21.53 seconds
# Processing time for pair David-Earl: 8.19 seconds
# CPU times: total: 406 ms
# Wall time: 1min 35s

# %%
# %%time
"""
sampling rate: 5h
--conf spark.driver.memory=6g ^
--conf spark.executor.memory=10g
"""
run_spatiotemporal_join(one_bird_pairs, id_field, join_id_field, sampling_rate_threshold, df, data_dir, broadcast_bounds, broadcast_spatial_bounds, attribute_list, select_columns, f"test_Earl_6_10_{sampling_rate}h")
# Out:
# Writing status every 1000 pairs
# Processing time for pair Earl-Hugh: 13.14 seconds
# Processing time for pair Earl-MooMoo: 7.53 seconds
# Processing time for pair Earl-Ethan: 13.91 seconds
# Processing time for pair Earl-Irma: 10.80 seconds
# Processing time for pair Earl-Leo: 11.41 seconds
# Processing time for pair Earl-Julie: 9.77 seconds
# Processing time for pair Earl-Gifford: 23.34 seconds
# Processing time for pair David-Earl: 10.53 seconds
# CPU times: total: 406 ms
# Wall time: 1min 41s

# %%
# %%time
"""
sampling rate: 4h
--conf spark.driver.memory=6g ^
--conf spark.executor.memory=10g
"""
run_spatiotemporal_join(one_bird_pairs, id_field, join_id_field, sampling_rate_threshold, df, data_dir, broadcast_bounds, broadcast_spatial_bounds, attribute_list, select_columns, f"test_Earl_6_10_{sampling_rate}h")
# Out:
# Writing status every 1000 pairs
# Processing time for pair Earl-Hugh: 15.44 seconds
# Processing time for pair Earl-MooMoo: 8.23 seconds
# Processing time for pair Earl-Ethan: 13.52 seconds
# Processing time for pair Earl-Irma: 11.52 seconds
# Processing time for pair Earl-Leo: 12.98 seconds
# Processing time for pair Earl-Julie: 12.36 seconds
# Processing time for pair Earl-Gifford: 23.70 seconds
# Processing time for pair David-Earl: 11.34 seconds
# CPU times: total: 438 ms
# Wall time: 1min 50s

# %%
# %%time
"""
sampling rate: 3h
--conf spark.driver.memory=6g ^
--conf spark.executor.memory=10g
"""
run_spatiotemporal_join(one_bird_pairs, id_field, join_id_field, sampling_rate_threshold, df, data_dir, broadcast_bounds, broadcast_spatial_bounds, attribute_list, select_columns, f"test_Earl_6_10_{sampling_rate}h")
# Out:
# Writing status every 1000 pairs
# Processing time for pair Earl-Hugh: 19.96 seconds
# Processing time for pair Earl-MooMoo: 11.97 seconds
# Processing time for pair Earl-Ethan: 16.28 seconds
# Processing time for pair Earl-Irma: 13.81 seconds
# Processing time for pair Earl-Leo: 15.69 seconds
# Processing time for pair Earl-Julie: 14.16 seconds
# Processing time for pair Earl-Gifford: 30.89 seconds
# Processing time for pair Black Knight-Earl: 12.58 seconds
# Processing time for pair David-Earl: 14.00 seconds
# CPU times: total: 641 ms
# Wall time: 2min 31s

# %%
# %%time
"""
sampling rate: 2h
--conf spark.driver.memory=6g ^
--conf spark.executor.memory=10g
"""
run_spatiotemporal_join(one_bird_pairs, id_field, join_id_field, sampling_rate_threshold, df, data_dir, broadcast_bounds, broadcast_spatial_bounds, attribute_list, select_columns, f"test_Earl_6_10_{sampling_rate}hh")
# Out:
# Writing status every 1000 pairs
# Processing time for pair Earl-Hugh: 23.81 seconds
# Processing time for pair Earl-MooMoo: 17.97 seconds
# Processing time for pair Earl-Ethan: 22.03 seconds
# Processing time for pair Earl-Irma: 16.98 seconds
# Processing time for pair Earl-Leo: 22.24 seconds
# Processing time for pair Earl-Julie: 20.40 seconds
# Processing time for pair Earl-Gifford: 57.37 seconds
# Processing time for pair Black Knight-Earl: 28.76 seconds
# Processing time for pair David-Earl: 30.25 seconds
# CPU times: total: 672 ms
# Wall time: 4min 1s

# %% [markdown]
# ### Configuration setting

# %%
# %%time
"""
--conf spark.driver.memory=6g ^
--conf spark.executor.memory=10g
"""
run_spatiotemporal_join(one_bird_pairs, id_field, join_id_field, sampling_rate_threshold, df, data_dir, broadcast_bounds, broadcast_spatial_bounds, attribute_list, select_columns, "test_Earl_6_10")
# Out:
# Writing status every 100 pairs
# Processing time for pair Earl-Hugh: 40.15 seconds
# Processing time for pair Earl-MooMoo: 31.81 seconds
# Processing time for pair Earl-Ethan: 37.23 seconds
# Processing time for pair Earl-Irma: 34.05 seconds
# Processing time for pair Earl-Leo: 40.31 seconds
# Processing time for pair Earl-Julie: 51.97 seconds
# Processing time for pair Earl-Gifford: 107.66 seconds
# Processing time for pair Black Knight-Earl: 36.43 seconds
# Processing time for pair David-Earl: 35.74 seconds
# CPU times: total: 516 ms
# Wall time: 6min 58s

# %%
# %%time
"""
--conf spark.driver.memory=5g ^
--conf spark.executor.memory=10g
"""
run_spatiotemporal_join(one_bird_pairs, id_field, join_id_field, sampling_rate_threshold, df, data_dir, broadcast_bounds, broadcast_spatial_bounds, attribute_list, select_columns, "test_Earl_5_10")
# Out:
# Writing status every 100 pairs
# Processing time for pair Earl-Hugh: 47.52 seconds
# Processing time for pair Earl-MooMoo: 32.97 seconds
# Processing time for pair Earl-Ethan: 39.39 seconds
# Processing time for pair Earl-Irma: 35.05 seconds
# Processing time for pair Earl-Leo: 40.70 seconds
# Processing time for pair Earl-Julie: 52.49 seconds
# Processing time for pair Earl-Gifford: 113.79 seconds
# Processing time for pair Black Knight-Earl: 37.34 seconds
# Processing time for pair David-Earl: 36.25 seconds
# CPU times: total: 578 ms
# Wall time: 7min 17s

# %%
# %%time
"""
--conf spark.driver.memory=5g ^
--conf spark.executor.memory=5g
"""
run_spatiotemporal_join(one_bird_pairs, id_field, join_id_field, sampling_rate_threshold, df, data_dir, broadcast_bounds, broadcast_spatial_bounds, attribute_list, select_columns, "test_Earl_5_5")
# Out:
# Writing status every 100 pairs
# Processing time for pair Earl-Hugh: 45.16 seconds
# Processing time for pair Earl-MooMoo: 30.72 seconds
# Processing time for pair Earl-Ethan: 38.81 seconds
# Processing time for pair Earl-Irma: 33.30 seconds
# Processing time for pair Earl-Leo: 40.68 seconds
# Processing time for pair Earl-Julie: 51.74 seconds
# Processing time for pair Earl-Gifford: 113.81 seconds
# Processing time for pair Black Knight-Earl: 37.41 seconds
# Processing time for pair David-Earl: 37.25 seconds
# CPU times: total: 703 ms
# Wall time: 7min 11s

# %%
# %%time
"""
--conf spark.driver.memory=5g ^
--conf spark.executor.memory=3g
"""
run_spatiotemporal_join(one_bird_pairs, id_field, join_id_field, sampling_rate_threshold, df, data_dir, broadcast_bounds, broadcast_spatial_bounds, attribute_list, select_columns, "test_Earl_5_3")
# Out:
# Writing status every 100 pairs
# Processing time for pair Earl-Hugh: 47.30 seconds
# Processing time for pair Earl-MooMoo: 33.82 seconds
# Processing time for pair Earl-Ethan: 35.56 seconds
# Processing time for pair Earl-Irma: 36.22 seconds
# Processing time for pair Earl-Leo: 40.50 seconds
# Processing time for pair Earl-Julie: 51.67 seconds
# Processing time for pair Earl-Gifford: 114.67 seconds
# Processing time for pair Black Knight-Earl: 36.64 seconds
# Processing time for pair David-Earl: 36.97 seconds
# CPU times: total: 672 ms
# Wall time: 7min 15s

# %%
# %%time
"""
--conf spark.driver.memory=10g ^
--conf spark.executor.memory=40g
"""
run_spatiotemporal_join(one_bird_pairs, id_field, join_id_field, sampling_rate_threshold, df, data_dir, broadcast_bounds, broadcast_spatial_bounds, attribute_list, select_columns, "test_Earl_10_40")
# Out:
# Writing status every 1000 pairs
# Processing time for pair Earl-Hugh: 41.11 seconds
# Processing time for pair Earl-MooMoo: 31.03 seconds
# Processing time for pair Earl-Ethan: 37.52 seconds
# Processing time for pair Earl-Irma: 34.77 seconds
# Processing time for pair Earl-Leo: 40.45 seconds
# Processing time for pair Earl-Julie: 50.29 seconds
# Processing time for pair Earl-Gifford: 101.22 seconds
# Processing time for pair Black Knight-Earl: 36.64 seconds
# Processing time for pair David-Earl: 36.00 seconds
# CPU times: total: 578 ms
# Wall time: 6min 51s

# %%
# check the output parquet for events
df_ppa = spark.read.format("parquet").load(f"{data_dir}\concurrent_intersect_PPAs_test_Earl_10_40")
df_ppa.show(5)
# Out:
# +----------+---------------------------+-------------------+-------------------+---------+--------+-------------+------------+-------------+--------------------------------+-------------------+-------------------+--------------+-------------+------------------+-----------------+----------------------+----------------------+------------------------+------------------------+------------------+------------------+------------------+-------------------+-------------+-------------+-------------------+--------------------+------------------+-------------+---------------+--------------------+--------------------+-----------------+-------------------+-------------------+--------------------+------------------+--------------------+--------------------+
# ...

# %%
# check the output parquet for events
df_result = spark.read.format("parquet").load(f"{data_dir}\concurrent_events_test_Earl_10_40")
df_result.show(5)
# Out:
# +---------------------+----+-----+-------------------+-------------------+-------------------+-------------------+------------------+-----------------+
# |continuous_segment_id|  p1|   p2|           p1_start|             p1_end|           p2_start|             p2_end|    max_difference|         duration|
# +---------------------+----+-----+-------------------+-------------------+-------------------+-------------------+------------------+-----------------+
# |                    1|Earl|Ethan|2015-07-16 12:18:02|2015-07-16 14:05:29|2015-07-16 12:37:00|2015-07-16 13:38:00|            0.9975|           107.45|
# |                    3|Earl|Ethan|2015-07-18 10:39:13|2015-07-18 11:39:22|2015-07-18 10:38:00|2015-07-18 11:39:00|0.9758333333333333|61.36666666666667|
# |                    5|Earl|Ethan|2015-07-19 10:59:57|2015-07-19 19:31:22|2015-07-19 10:38:00|2015-07-19 18:48:00|0.9997222222222222|533.3666666666667|
# ...

# %% [markdown]
# ## Full Dataset
# ### Configuration setting

# %%
# %%time
"""
--conf spark.driver.memory=6g ^
--conf spark.executor.memory=10g
"""
run_spatiotemporal_join(pairs, id_field, join_id_field, sampling_rate_threshold, df, data_dir, broadcast_bounds, broadcast_spatial_bounds, attribute_list, select_columns, "All_run3")
# Out:
# Writing status every 1000 pairs
# Processing time for pair Cinco-Fenix: 32.19 seconds
# Processing time for pair Cinco-Whitey: 17.97 seconds
# Processing time for pair Cinco-Two-thirds: 36.66 seconds
# Processing time for pair Cinco-Halfway: 32.04 seconds
# Processing time for pair Cinco-Mandeb: 16.56 seconds
# Processing time for pair Cinco-Young Luro: 19.20 seconds
# Processing time for pair Steve-Tekoa: 39.37 seconds
# Processing time for pair Steve-Tire Pile: 35.52 seconds
# Processing time for pair Steve-Tintin: 36.37 seconds
# Processing time for pair Steve-Superior: 33.90 seconds
# Processing time for pair Steve-Versace: 49.99 seconds
# Processing time for pair Steve-Thomas: 32.63 seconds
# Processing time for pair Mary-Steamhouse 1: 19.03 seconds
# Processing time for pair Mary-Steamhouse 2: 16.14 seconds
# Processing time for pair Schaumboch-Sill: 30.74 seconds
# Processing time for pair Prado-Steamhouse 1: 26.29 seconds
# ...

# %%
# %%time
"""
--conf spark.driver.memory=10g ^
--conf spark.executor.memory=40g
Unnecessary
"""
run_spatiotemporal_join(pairs, id_field, join_id_field, sampling_rate_threshold, df, data_dir, broadcast_bounds, broadcast_spatial_bounds, attribute_list, select_columns, "All_run2")
# Out:
# Writing status every 1000 pairs
# Processing time for pair Cinco-Fenix: 36.49 seconds
# Processing time for pair Cinco-Whitey: 17.55 seconds
# Processing time for pair Cinco-Two-thirds: 37.28 seconds
# Processing time for pair Cinco-Halfway: 31.88 seconds
# Processing time for pair Cinco-Mandeb: 16.37 seconds
# Processing time for pair Cinco-Young Luro: 17.94 seconds
# Processing time for pair Steve-Tekoa: 40.86 seconds
# Processing time for pair Steve-Tire Pile: 35.65 seconds
# Processing time for pair Steve-Tintin: 36.27 seconds
# Processing time for pair Steve-Superior: 34.27 seconds
# Processing time for pair Steve-Versace: 49.77 seconds
# Processing time for pair Steve-Thomas: 32.75 seconds
# Processing time for pair Mary-Steamhouse 1: 18.23 seconds
# Processing time for pair Mary-Steamhouse 2: 15.91 seconds
# Processing time for pair Schaumboch-Sill: 30.23 seconds
# Processing time for pair Prado-Steamhouse 1: 25.27 seconds
# ...

# %% [markdown]
# # Delayed Interaction Performance

# %% [markdown]
# ## Earl Subset

# %%
# %%time
"""
--conf spark.driver.memory=6g ^
--conf spark.executor.memory=10g
"""
run_delay_spatiotemporal_join(one_bird_pairs, id_field, join_id_field, df, data_dir, broadcast_bounds, broadcast_spatial_bounds, attribute_list, select_columns, "test_Earl_6_10", 28)
# Out:
# Writing status every 100 pairs
# Processing time for pair Earl-Hugh: 116.36 seconds
# Processing time for pair Earl-MooMoo: 30.20 seconds
# Processing time for pair Earl-Ethan: 63.84 seconds
# Processing time for pair Earl-Irma: 30.20 seconds
# Processing time for pair Earl-Leo: 38.21 seconds
# Processing time for pair Earl-Julie: 45.57 seconds
# Processing time for pair Earl-Gifford: 507.86 seconds
# Processing time for pair Black Knight-Earl: 30.60 seconds
# Processing time for pair David-Earl: 33.49 seconds
# CPU times: total: 609 ms
# Wall time: 14min 56s

# %%
# %%time
filter_delay_PPAs(delay4w_test_df, id_field, join_id_field, data_dir, "test_Earl")
# Out:
# CPU times: total: 219 ms
# Wall time: 1min 31s

# %% [markdown]
# ## Full dataset

# %%
# %%time
"""
--conf spark.driver.memory=10g ^
--conf spark.executor.memory=40g
"""
run_delay_spatiotemporal_join(pairs, id_field, join_id_field, df, data_dir, broadcast_bounds, broadcast_spatial_bounds, attribute_list, select_columns, "All", 28)
# Out:
# Writing status every 100 pairs
# Processing time for pair Cinco-Fenix: 56.64 seconds
# Processing time for pair Cinco-Whitey: 16.30 seconds
# Processing time for pair Cinco-Two-thirds: 37.02 seconds
# Processing time for pair Cinco-Halfway: 32.68 seconds
# Processing time for pair Cinco-Mandeb: 15.40 seconds
# Processing time for pair Cinco-Young Luro: 16.59 seconds
# Processing time for pair Steve-Tekoa: 33.79 seconds
# Processing time for pair Steve-Tire Pile: 30.91 seconds
# Processing time for pair Steve-Tintin: 32.02 seconds
# Processing time for pair Steve-Superior: 29.87 seconds
# Processing time for pair Steve-Versace: 45.43 seconds
# Processing time for pair Steve-Thomas: 33.30 seconds
# Processing time for pair Mary-Steamhouse 1: 16.39 seconds
# Processing time for pair Mary-Steamhouse 2: 14.68 seconds
# ...100 finished
# Processing time for pair Schaumboch-Sill: 28.97 seconds
# Processing time for pair Prado-Steamhouse 1: 25.81 seconds
# ...

# %%
# %%time
filter_delay_PPAs(delay4w_all_df, id_field, join_id_field, data_dir, "All")
# Out:
# CPU times: total: 172 ms
# Wall time: 7min 31s
